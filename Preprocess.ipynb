# %%
import pandas as pd
# Load the CSV file into a pandas DataFrame
df = pd.read_csv('Hacking_Trends (1).csv')

# %%
df
# Out:
#                                              title_link  \
# 0     https://thehackernews.com/2024/02/meta-warns-o...
# 1     https://thehackernews.com/2024/02/bye-bye-siem...
# 2       https://thehackernews.uk/state-of-ai-cloud-2024
# 3     https://thehackernews.com/2024/02/anatsa-andro...
# 4     https://thehackernews.com/2024/02/russian-link...
# ...                                                 ...
# 1304  https://thehackernews.com/2023/06/microsoft-wa...
# 1305  https://thehackernews.com/2023/06/chinese-hack...
# 1306  https://thehackernews.com/2023/06/us-cybersecu...
# 1307  https://thehackernews.com/2023/06/twitter-hack...
# 1308  https://thehackernews.com/2023/06/cybercrime-g...
#
#                                                  titles    posted_date  \
# 0       Meta Warns of 8 Spyware Firms Targeting iOS,...   Feb 19, 2024
# 1       How to Achieve the Best Risk-Based Alerting ...   Feb 19, 2024
# 2                                                   NaN            NaN
# ...

# %%
# Find missing values
missing_values = df.isnull().sum()

# Print the number of missing values in each column
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# title_link        0
# titles          131
# posted_date     131
# hacking_type    151
# text_loc        151
# dtype: int64

# %%
# Convert 'posted_date' column to datetime format with 'mixed' option
df['posted_date'] = pd.to_datetime(df['posted_date'], format='mixed')

# Convert 'posted_date' column to 'yyyy-mm-dd' format
df['posted_date'] = df['posted_date'].dt.strftime('%Y-%m-%d')

# %%
df
# Out:
#                                              title_link  \
# 0     https://thehackernews.com/2024/02/meta-warns-o...
# 1     https://thehackernews.com/2024/02/bye-bye-siem...
# 2       https://thehackernews.uk/state-of-ai-cloud-2024
# 3     https://thehackernews.com/2024/02/anatsa-andro...
# 4     https://thehackernews.com/2024/02/russian-link...
# ...                                                 ...
# 1304  https://thehackernews.com/2023/06/microsoft-wa...
# 1305  https://thehackernews.com/2023/06/chinese-hack...
# 1306  https://thehackernews.com/2023/06/us-cybersecu...
# 1307  https://thehackernews.com/2023/06/twitter-hack...
# 1308  https://thehackernews.com/2023/06/cybercrime-g...
#
#                                                  titles posted_date  \
# 0       Meta Warns of 8 Spyware Firms Targeting iOS,...  2024-02-19
# 1       How to Achieve the Best Risk-Based Alerting ...  2024-02-19
# 2                                                   NaN         NaN
# ...

# %%
# Replace inconsistent delimiter with a consistent one
# Replace inconsistent delimiter with a consistent one
df['hacking_type'] = df['hacking_type'].str.replace('/ ', '/')

# Split 'hacking_type' into two columns using the '/' character as the delimiter
df[['hacking_type', 'hacking_sub_type']] = df['hacking_type'].str.split('/', n=1, expand=True)

# %%
df
# Out:
#                                              title_link  \
# 0     https://thehackernews.com/2024/02/meta-warns-o...
# 1     https://thehackernews.com/2024/02/bye-bye-siem...
# 2       https://thehackernews.uk/state-of-ai-cloud-2024
# 3     https://thehackernews.com/2024/02/anatsa-andro...
# 4     https://thehackernews.com/2024/02/russian-link...
# ...                                                 ...
# 1304  https://thehackernews.com/2023/06/microsoft-wa...
# 1305  https://thehackernews.com/2023/06/chinese-hack...
# 1306  https://thehackernews.com/2023/06/us-cybersecu...
# 1307  https://thehackernews.com/2023/06/twitter-hack...
# 1308  https://thehackernews.com/2023/06/cybercrime-g...
#
#                                                  titles posted_date  \
# 0       Meta Warns of 8 Spyware Firms Targeting iOS,...  2024-02-19
# 1       How to Achieve the Best Risk-Based Alerting ...  2024-02-19
# 2                                                   NaN         NaN
# ...

# %%
# Find missing values
missing_values = df.isnull().sum()

# Print the number of missing values in each column
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# title_link            0
# titles              131
# posted_date         131
# hacking_type        151
# text_loc            151
# hacking_sub_type    310
# dtype: int64

# %%
# Remove rows with missing values
df = df.dropna()

# %%
# Find missing values
missing_values = df.isnull().sum()

# Print the number of missing values in each column
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# title_link          0
# titles              0
# posted_date         0
# hacking_type        0
# text_loc            0
# hacking_sub_type    0
# dtype: int64

# %%
df
# Out:
#                                              title_link  \
# 0     https://thehackernews.com/2024/02/meta-warns-o...
# 3     https://thehackernews.com/2024/02/anatsa-andro...
# 4     https://thehackernews.com/2024/02/russian-link...
# 5     https://thehackernews.com/2024/02/iranian-hack...
# 6     https://thehackernews.com/2024/02/fbis-most-wa...
# ...                                                 ...
# 1304  https://thehackernews.com/2023/06/microsoft-wa...
# 1305  https://thehackernews.com/2023/06/chinese-hack...
# 1306  https://thehackernews.com/2023/06/us-cybersecu...
# 1307  https://thehackernews.com/2023/06/twitter-hack...
# 1308  https://thehackernews.com/2023/06/cybercrime-g...
#
#                                                  titles posted_date  \
# 0       Meta Warns of 8 Spyware Firms Targeting iOS,...  2024-02-19
# 3       Anatsa Android Trojan Bypasses Google Play S...  2024-02-19
# 4       Russian-Linked Hackers Target 80+ Organizati...  2024-02-19
# ...

# %%
# Drop a column named 'column_to_drop'
df.drop(columns=['text_loc'], inplace=True)

# Display the updated DataFrame
df
# Out:
# C:\Users\alroy\AppData\Local\Temp\ipykernel_19680\2275674764.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['text_loc'], inplace=True)
#                                              title_link  \
# 0     https://thehackernews.com/2024/02/meta-warns-o...
# 3     https://thehackernews.com/2024/02/anatsa-andro...
# 4     https://thehackernews.com/2024/02/russian-link...
# 5     https://thehackernews.com/2024/02/iranian-hack...
# 6     https://thehackernews.com/2024/02/fbis-most-wa...
# ...                                                 ...
# 1304  https://thehackernews.com/2023/06/microsoft-wa...
# 1305  https://thehackernews.com/2023/06/chinese-hack...
# 1306  https://thehackernews.com/2023/06/us-cybersecu...
# 1307  https://thehackernews.com/2023/06/twitter-hack...
# ...

# %%
df.to_csv('cleaned_dataset2.csv', index=False)
