# %%
import pandas as pd
dataset = pd.read_csv("Hacking_Trends.csv")
dataset
# Out:
#                                              title_link  \
# 0     https://thehackernews.com/2024/02/meta-warns-o...
# 1     https://thehackernews.com/2024/02/bye-bye-siem...
# 2       https://thehackernews.uk/state-of-ai-cloud-2024
# 3     https://thehackernews.com/2024/02/anatsa-andro...
# 4     https://thehackernews.com/2024/02/russian-link...
# ...                                                 ...
# 1304  https://thehackernews.com/2023/06/microsoft-wa...
# 1305  https://thehackernews.com/2023/06/chinese-hack...
# 1306  https://thehackernews.com/2023/06/us-cybersecu...
# 1307  https://thehackernews.com/2023/06/twitter-hack...
# 1308  https://thehackernews.com/2023/06/cybercrime-g...
#
#                                                  titles    posted_date  \
# 0       Meta Warns of 8 Spyware Firms Targeting iOS,...   Feb 19, 2024
# 1       How to Achieve the Best Risk-Based Alerting ...   Feb 19, 2024
# 2                                                   NaN            NaN
# ...

# %%
#Data types
dataset.dtypes
# Out:
# title_link      object
# titles          object
# posted_date     object
# hacking_type    object
# text_loc        object
# dtype: object

# %%
import warnings
warnings.filterwarnings("ignore")
dataset.describe()
# Out:
#                                                title_link  \
# count                                                1309
# unique                                               1072
# top     https://thehackernews.com/2024/02/hands-on-rev...
# freq                                                  120
#
#                                                    titles    posted_date  \
# count                                                1178           1178
# unique                                               1059            212
# top       Hands-on Review: Myrror Security Code-Aware ...   Feb 09, 2024
# freq                                                  120            127
#
#                  hacking_type text_loc
# count                    1158     1158
# unique                    651     1038
# top      Static Code Analysis
# freq                      120      120

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title_link    1309 non-null   object
#  1   titles        1178 non-null   object
#  2   posted_date   1178 non-null   object
#  3   hacking_type  1158 non-null   object
#  4   text_loc      1158 non-null   object
# dtypes: object(5)
# memory usage: 51.3+ KB

# %%
print(dataset.head())
# Out:
#                                           title_link  \
# 0  https://thehackernews.com/2024/02/meta-warns-o...
# 1  https://thehackernews.com/2024/02/bye-bye-siem...
# 2    https://thehackernews.uk/state-of-ai-cloud-2024
# 3  https://thehackernews.com/2024/02/anatsa-andro...
# 4  https://thehackernews.com/2024/02/russian-link...
#
#                                               titles posted_date  \
# 0    Meta Warns of 8 Spyware Firms Targeting iOS,...  2024-02-19
# 1    How to Achieve the Best Risk-Based Alerting ...  2024-02-19
# 2                                                NaN         NaN
# 3    Anatsa Android Trojan Bypasses Google Play S...  2024-02-19
# 4    Russian-Linked Hackers Target 80+ Organizati...  2024-02-19
#
#                       hacking_type  \
# 0                 Mobile Security
# 1   Network Detection and Response
# 2                              NaN
# 3                         Malware
# 4                 Cyber Espionage
#
# ...
